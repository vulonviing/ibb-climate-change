# %%
pip install meteostat
# Out:
# Collecting meteostatNote: you may need to restart the kernel to use updated packages.
#
#   Downloading meteostat-1.6.5-py3-none-any.whl (31 kB)
# Requirement already satisfied: pandas>=1.1 in c:\users\emrecan.ulu.desktop-4t87dph\appdata\local\programs\python\python37\lib\site-packages (from meteostat) (1.3.5)
# Requirement already satisfied: pytz in c:\users\emrecan.ulu.desktop-4t87dph\appdata\local\programs\python\python37\lib\site-packages (from meteostat) (2023.3)
# Requirement already satisfied: numpy in c:\users\emrecan.ulu.desktop-4t87dph\appdata\local\programs\python\python37\lib\site-packages (from meteostat) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\emrecan.ulu.desktop-4t87dph\appdata\local\programs\python\python37\lib\site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\emrecan.ulu.desktop-4t87dph\appdata\local\programs\python\python37\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.1->meteostat) (1.16.0)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.5
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31)

# Create Point for Vancouver, BC
location = Point(41.0082, 28.9784)

# Get daily data for 2018
data = Daily(location, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
data
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2018-01-01   8.9   7.5  10.7   NaN   NaN  213.0  17.8   NaN  1017.6   NaN
# 2018-01-02  10.8   8.0  13.2   NaN   NaN    NaN   9.5   NaN  1011.0   NaN
# 2018-01-03  10.8   9.0  12.1   NaN   NaN    NaN  12.5   NaN  1008.4   NaN
# 2018-01-04   9.8   8.9  12.0   NaN   NaN  331.0  12.9   NaN  1006.1   NaN
# 2018-01-05   8.7   7.9  10.0   NaN   NaN    NaN  15.5   NaN  1013.1   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2018-12-27   4.3   0.0   7.0   NaN   NaN  321.0   9.9   NaN  1023.6   NaN
# 2018-12-28   6.0   2.0   9.0   NaN   NaN  262.0  10.1   NaN  1023.5   NaN
# 2018-12-29   6.9   6.0   8.0   NaN   NaN  251.0  15.9   NaN  1020.0   NaN
# 2018-12-30   6.3   5.0   7.0   NaN   NaN  348.0  10.7   NaN  1023.7   NaN
# 2018-12-31   6.8   4.0  10.0   NaN   NaN   71.0  11.3   NaN  1023.2   NaN
#
# [365 rows x 10 columns]
